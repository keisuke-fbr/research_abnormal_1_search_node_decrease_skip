# %%
#必要ライブラリのインストール
from src.data import data_complete
from src.model import result
from src.store import store
from src.store import read
from src.plot import plot_all
from src.plot import plot_predict
from src.plot import data_describe
from src.plot import plot_final_loss_vs_unit_sum
from src.custom_class import ConsecutiveEpochsEarlyStopping

import warnings

# 全ての警告を無視
warnings.filterwarnings('ignore', category=UserWarning)

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # エラーのみ表示

# %%
#データの読み込み及び加工、コラムリストの取得
colums_list, data_ex, data_original = data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %%
#データの確認
data_ex
# Out:
#        processor_unit_units_status_cpu_board_cpu_fan  \
# 0                                           0.735761
# 1                                           0.766849
# 2                                           0.797937
# 3                                           0.834207
# 4                                           0.735761
# ...                                              ...
# 26420                                       0.378248
# 26421                                       0.378248
# 26422                                       0.378248
# 26423                                       0.378248
# 26424                                       0.347160
#
#        processor_unit_units_status_cpu_board_cpu_bd_fan1  \
# 0                                               0.562054
# 1                                               0.649645
# 2                                               0.562054
# 3                                               0.562054
# 4                                               0.474463
# ...                                                  ...
# 26420                                           0.364974
# 26421                                           0.364974
# 26422                                           0.277382
# 26423                                           0.364974
# 26424                                           0.306579
#
#        processor_unit_units_status_cpu_board_cpu_bd_fan2  \
# 0                                               0.902923
# 1                                               0.913514
# 2                                               0.928518
# 3                                               0.924988
# 4                                               0.924988
# ...                                                  ...
# 26420                                           0.688448
# 26421                                           0.792596
# 26422                                           0.765235
# 26423                                           0.724635
# 26424                                           0.480151
#
#        processor_unit_units_status_cpu_board_cpu_bd_temp  \
# 0                                               0.740751
# 1                                               0.777788
# 2                                               0.814825
# 3                                               0.814825
# 4                                               0.777788
# ...                                                  ...
# 26420                                           0.444454
# 26421                                           0.444454
# 26422                                           0.444454
# 26423                                           0.444454
# 26424                                           0.444454
#
#        processor_unit_units_status_cpu_board_cpu_core_temp  \
# 0                                               0.638899
# 1                                               0.666677
# 2                                               0.694454
# 3                                               0.694454
# 4                                               0.666677
# ...                                                  ...
# 26420                                           0.361121
# 26421                                           0.361121
# 26422                                           0.333343
# 26423                                           0.333343
# 26424                                           0.305566
#
#        processor_unit_units_status_cpu_board_gpu_core_temp  \
# 0                                               0.633343
# 1                                               0.666677
# 2                                               0.700010
# 3                                               0.700010
# 4                                               0.633343
# ...                                                  ...
# 26420                                           0.466677
# 26421                                           0.500010
# 26422                                           0.466677
# 26423                                           0.466677
# 26424                                           0.466677
#
#        processor_unit_units_status_cpu_board_cpu_core_vol  \
# 0                                               0.324796
# 1                                               0.977218
# 2                                               0.868956
# 3                                               0.817674
# 4                                               0.524227
# ...                                                  ...
# 26420                                           0.868956
# 26421                                           0.834768
# 26422                                           0.735053
# 26423                                           0.501435
# 26424                                           0.900295
#
#        processor_unit_units_status_cpu_board_cpu_bd_vbat  \
# 0                                               0.393949
# 1                                               0.181828
# 2                                               0.181828
# 3                                               0.181828
# 4                                               0.393949
# ...                                                  ...
# 26420                                           0.000010
# 26421                                           0.000010
# 26422                                           0.000010
# 26423                                           0.000010
# 26424                                           0.000010
#
#        processor_unit_units_status_cpu_board_cpu_bd_p3_3v  \
# 0                                                0.68001
# 1                                                0.68001
# 2                                                0.84001
# 3                                                0.68001
# 4                                                0.68001
# ...                                                  ...
# 26420                                            0.68001
# 26421                                            0.00001
# 26422                                            0.68001
# 26423                                            0.68001
# 26424                                            0.68001
#
#        processor_unit_units_status_cpu_board_cpu_bd_p5v  \
# 0                                               0.00001
# 1                                               0.00001
# 2                                               0.00001
# 3                                               0.00001
# 4                                               0.80001
# ...                                                 ...
# 26420                                           1.00001
# 26421                                           1.00001
# 26422                                           1.00001
# 26423                                           1.00001
# 26424                                           1.00001
#
#        processor_unit_units_status_cpu_board_cpu_bd_p12v    measurement_date
# 0                                               0.073539 2015-12-22 06:15:00
# 1                                               0.000010 2015-12-22 07:00:02
# 2                                               0.073539 2015-12-22 08:00:03
# 3                                               0.073539 2015-12-22 09:00:03
# 4                                               0.073539 2015-12-22 10:00:03
# ...                                                  ...                 ...
# 26420                                           1.000010 2019-02-04 19:00:02
# 26421                                           1.000010 2019-02-04 20:00:02
# 26422                                           1.000010 2019-02-04 21:00:02
# 26423                                           1.000010 2019-02-04 22:00:02
# 26424                                           1.000010 2019-02-04 23:00:02
#
# [26425 rows x 12 columns]

# %% [markdown]
# ここからモデルの作成に入る

# %%
#ハイパーパラメータの設定

#オートエンコーダの重みの初期化方法
initializer = "glorot_normal"


#モデルの最小化関数のパラメータ
delta = 0.5

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
error_threshold = 0.002
error_threshold = 0.16

# EarlyStoppingの設定
early_stopping_params = {
    'monitor': 'loss',
    'patience': 1,
    'min_delta': 0.1,
    'restore_best_weights': True,
    'verbose': 0,
    'mode': 'min'
}

# %%
#実験の実行及び結果の格納
results_df, traindata_model_df, thresholds, loss_values = result(data_ex, colums_list,  initializer, error_threshold, max_epochs, early_stopping_params, units )
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=30, units_2=10, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=30, units_2=10
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=27, units_2=10, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=27, units_2=10
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=24, units_2=10, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=24, units_2=10
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=21, units_2=10, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした1回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=21, units_2=10, 初期化方法=glorot_normal, 試行回数=2
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=21, units_2=10
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=18, units_2=10, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした1回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=18, units_2=10, 初期化方法=glorot_normal, 試行回数=2
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした2回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=18, units_2=10, 初期化方法=glorot_normal, 試行回数=3
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした3回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=18, units_2=10, 初期化方法=glorot_normal, 試行回数=4
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした4回目
# 初期化4回すべてで閾値を上回りました: units_1_3=18, units_2=10
# ノード数を上げて探索を続けます
# unit1_3=19の探索
# unit1_3=19の探索：初期化1回目
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 詳細探索で閾値を満たすモデルを発見: units_1_3=19, units_2=10
# 次のunit2の探索に移ります
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=30, units_2=9, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=30, units_2=9
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=27, units_2=9, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした1回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=27, units_2=9, 初期化方法=glorot_normal, 試行回数=2
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=27, units_2=9
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=24, units_2=9, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした1回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=24, units_2=9, 初期化方法=glorot_normal, 試行回数=2
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした2回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=24, units_2=9, 初期化方法=glorot_normal, 試行回数=3
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=24, units_2=9
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=21, units_2=9, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした1回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=21, units_2=9, 初期化方法=glorot_normal, 試行回数=2
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした2回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=21, units_2=9, 初期化方法=glorot_normal, 試行回数=3
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした3回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=21, units_2=9, 初期化方法=glorot_normal, 試行回数=4
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした4回目
# 初期化4回すべてで閾値を上回りました: units_1_3=21, units_2=9
# ノード数を上げて探索を続けます
# unit1_3=22の探索
# unit1_3=22の探索：初期化1回目
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした
# unit1_3=22の探索：初期化2回目
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした
# unit1_3=22の探索：初期化3回目
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 詳細探索で閾値を満たすモデルを発見: units_1_3=22, units_2=9
# 次のunit2の探索に移ります
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=30, units_2=8, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=30, units_2=8
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=27, units_2=8, 初期化方法=glorot_normal, 試行回数=1
# モデルは収束しました。訓練は 2 エポックで停止しました。
# 閾値を下回りませんでした1回目
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=27, units_2=8, 初期化方法=glorot_normal, 試行回数=2
# モデルは収束しました。訓練は 3 エポックで停止しました。
# 閾値を下回るモデルを発見: units_1_3=27, units_2=8
# ----------------------------------------------------------------------------------------
# 探索中: units_1_3=24, units_2=8, 初期化方法=glorot_normal, 試行回数=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 #実験の実行及び結果の格納
# ----> 2 results_df, traindata_model_df, thresholds, loss_values = result(data_ex, colums_list,  initializer, error_threshold, max_epochs, early_stopping_params, units )
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\src\model.py:341, in result(data_ex, colums_list, initializer, error_threshold, max_epochs, early_stopping_params, units, num)
#     338 print(str(i+1) + "回目の期間のトレーニングデータ数:" + str(len(train_data)))
#     340 #モデルの作成
# --> 341 best_model, final_losses_per_units = search_model(initializer,train_data, error_threshold, max_epochs, early_stopping_params, units)
#     344 for key, value in final_losses_per_units.items():
#     345     add_to_dict_with_average(loss_values, key, value)
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\src\model.py:179, in search_model(initializer, X_train, error_threshold, max_epochs, early_stopping_params, units, num_initializations)
#     176 print(f"探索中: units_1_3={units_1_3}, units_2={units_2}, 初期化方法={initializer}, 試行回数={init_num+1}")
#     178 model = model_autoencoder(initializer, units_1_3, units_2)
# --> 179 final_loss = train_and_evaluate(model, X_train, max_epochs, early_stopping_params)
#     180 final_losses_for_units.append(final_loss)
#     182 if final_loss < error_threshold:
#     183     # 閾値を下回った場合、次へ進む
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\src\model.py:126, in train_and_evaluate(model, X_train, max_epochs, early_stopping_params)
#     124 history = 0
#     125 #ここでの終了条件はあくまでも収束条件
# --> 126 history = model.fit(X_train, X_train, epochs=max_epochs, batch_size=64, verbose=0
#     127                     , shuffle = True, validation_data = (X_train,X_train) ,callbacks=[early_stopping])
#     129 # EarlyStoppingで打ち切られたかどうかを確認する
#     130 if len(history.epoch) < max_epochs:
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 for step, iterator in epoch_iterator.enumerate_epoch():
#     317     callbacks.on_train_batch_begin(step)
# --> 318     logs = self.train_function(iterator)
#     319     logs = self._pythonify_logs(logs)
#     320     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File c:\Users\小山佳祐\Desktop\研究元ファイル\abnormal\research_abnormal_1_search_node_decrease_skip\venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#結果の保存
store(results_df,"model_1")
store(thresholds,"thresholds_1")
store(traindata_model_df, "traindata_model_df_1")

# %%
#結果の抜き出し
results_df = read("model_1")
thresholds = read("thresholds_1")
traindata_model_df = read("traindata_model_df_1")

# %%
#結果のプロット
plot_all(results_df,thresholds, colums_list, data_original)

# %%
plot_predict(traindata_model_df, colums_list, data_ex)

# %%
#収束の確認
plot_final_loss_vs_unit_sum(loss_values)
print(len(loss_values))

# %%
#モジュールの再リロード
import importlib
import src
import src.model

importlib.reload(src.model)
importlib.reload(src.plot)

#必要ライブラリのインストール
from src.data import data_complete
from src.model import result
from src.store import store
from src.store import read
from src.plot import plot_all
from src.plot import plot_predict
from src.plot import data_describe
from src.plot import plot_final_loss_vs_unit_sum
from src.custom_class import ConsecutiveEpochsEarlyStopping
